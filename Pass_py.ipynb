# %% [markdown]
# <a href="https://colab.research.google.com/github/fathima123-456/Password-Generator-/blob/main/Pass_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

print("=== Password Generator ===")

# Ask user password length
length = int(input("Enter password length: "))

# Characters used in password
characters = string.ascii_letters + string.digits + string.punctuation

# Generate password
password = ""
for i in range(length):
    password += random.choice(characters)

# Display password
print("Generated Password:", password)
# Out:
# === Password Generator ===
# Enter password length: 6
# Generated Password: 2,nX8R
